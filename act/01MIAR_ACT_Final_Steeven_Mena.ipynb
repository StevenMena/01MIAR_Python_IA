# %% [markdown]
# <img src="https://github.com/StevenMena/01MIAR_Python_IA/blob/main/img/viu_logo.png?raw=1" width="200">
#
# ## 01MIAR - Actividad Final
# ##Nombres: Steven Mena
#
# ### Introducción
#
# Python es uno de los lenguajes de programación de referencia en el ámbito del tratamiento y análisis de datos. Existen diferentes funciones internas de Python y librerías que permiten mejorar la eficiencia de estos trabajos como es el caso de NumPy para el cálculo numérico y Pandas para operaciones con datos estructurados. Junto con estas operaciones, la visualización es un proceso importante para comprender mejor los datos. Con Matplotlib combinado con Pandas, y en el entorno Jupyter, es posible desarrollar y explicar el proceso de tratamiento y análisis de datos con gran facilidad.
#
# ### Objetivo
#
# - Aplicar diferentes técnicas de tratamiento de datos explicadas durante el curso
# - Explorar datos y evaluarlos mediante el uso de Pandas
# - Aplicar adecuadamente técnicas de visualización
# - Desarrollar una capacidad crítica y conocer fuentes de información
#
# ##El dataset escogido es sobre las distintas aplicaciones moviles que existen para  Apple
# #Fuente: https://www.kaggle.com/datasets/ramamet4/app-store-apple-data-set-10k-apps

# %% [markdown]
# #Importar librerías

# %%
#Dos líbrerias fundamentales en python para el manejo de datos
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt #Librería para plotear o gráficar
import os #Líbreria para manipulación de archivos 
import seaborn as sns #Líbreria que no sirve para crear gráficos o plotear dinámicamente

# %% [markdown]
# ##Cargar dataset
# El dataset es un archivo en formato csv.
# Para cargar el dataset lo podemos hacer con la librería os o directamente con pandas con su función read_csv.
# Para este trabajo se van ocupar dos dataset, que se relacionan por medio del id de la aplicación movil.

# %%
#Si nuestro archivo esta en la misma ubicación que este notebook, no necesitamos especificar su folder o la ruta
ruta_dataset = os.path.join('AppleStore.csv')
#Especificamos la ruta del archivo, su carácter como separación, el motor y si posse index propio
#Se almancena el csv en un objeto dataframe de panda
apple_mobile_apps = pd.read_csv(ruta_dataset, sep=',', index_col=0, engine='python')


#Cargando el segundo dataset
#Esta vez demostramos que se puede cargar un dataset en formato csv directamente con la libería pandas
apple_mobile_apps_desc = pd.read_csv('appleStore_description.csv', sep=',', index_col=0, engine='python')

# %% [markdown]
# ##Visualización de un dataset

# %%
#función para mostrar todos los datos del dataset
display(apple_mobile_apps)

display(apple_mobile_apps_desc)
# Out:
#                id                                         track_name  \
# 1       281656475                                    PAC-MAN Premium
# 2       281796108                          Evernote - stay organized
# 3       281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 4       282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 5       282935706                                              Bible
# ...           ...                                                ...
# 11081  1187617475                                              Kubik
# 11082  1187682390                                  VR Roller-Coaster
# 11087  1187779532              Bret Michaels Emojis + Lyric Keyboard
# 11089  1187838770          VR Roller Coaster World - Virtual Reality
# 11097  1188375727                       Escape the Sweet Shop Series
#
#        size_bytes currency  price  rating_count_tot  rating_count_ver  \
# ...

# %%
#Visualizar solo 10 filas de un dataset
display(apple_mobile_apps.sample(10))

#Visualizar solo los primeros elementos de un dataset
display(apple_mobile_apps.head(5))

#Visualizar solo los últimos elementos de un dataset
display(apple_mobile_apps.tail(1))
# Out:
#                id                      track_name  size_bytes currency  price  \
# 3648    924826403                      The Swords    48083968      USD   1.99
# 7373   1085932516                  勘違い探し（俺のこと・・・）    32477184      USD   0.00
# 10367  1159611436                       Just Trap   191611904      USD   0.00
# 6241   1062164103      マンガきゅんと‐漫画が全話読み放題の少女まんがアプリ    36295680      USD   0.00
# 3689    930304174                      Scary Doll    16478208      USD   3.99
# 3746    934510730               Astropad Standard    25945088      USD  29.99
# 1830    566685699                         We Maps    38597632      USD   6.99
# 8259   1104879125  애드픽 - 인플루언서가 되어 의미있는 수익을 올리세요!    28006400      USD   0.00
# 7458   1087273941       女性向けまとめ読みアプリ - pool（プール）-    89447424      USD   0.00
# 9464   1132336222                          Bridge   100835328      USD   0.00
#
#        rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# ...

# %% [markdown]
# ##Datos generales de un dataset

# %%
# Muestra los tipos de datos de cada columna
apple_mobile_apps.dtypes
# Out:
# id                    int64
# track_name           object
# size_bytes            int64
# currency             object
# price               float64
# rating_count_tot      int64
# rating_count_ver      int64
# user_rating         float64
# user_rating_ver     float64
# ver                  object
# cont_rating          object
# prime_genre          object
# sup_devices.num       int64
# ipadSc_urls.num       int64
# lang.num              int64
# vpp_lic               int64
# dtype: object

# %%
# Muestra información estadistica sobre cada columna del dataset
display(apple_mobile_apps.describe())
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       7197.000000  7197.000000      7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578        37.361817
# std         3920.455183     1.517948         1.809363         3.737715
# min            0.000000     0.000000         0.000000         9.000000
# ...

# %%
#Info general del dataset
apple_mobile_apps.info()

#Dimensiones del dataset
apple_mobile_apps.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7197 entries, 1 to 11097
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7197 non-null   int64
#  1   track_name        7197 non-null   object
#  2   size_bytes        7197 non-null   int64
#  3   currency          7197 non-null   object
#  4   price             7197 non-null   float64
#  5   rating_count_tot  7197 non-null   int64
#  6   rating_count_ver  7197 non-null   int64
#  7   user_rating       7197 non-null   float64
#  8   user_rating_ver   7197 non-null   float64
#  9   ver               7197 non-null   object
#  10  cont_rating       7197 non-null   object
#  11  prime_genre       7197 non-null   object
#  12  sup_devices.num   7197 non-null   int64
#  13  ipadSc_urls.num   7197 non-null   int64
#  14  lang.num          7197 non-null   int64
#  15  vpp_lic           7197 non-null   int64
# ...

# %% [markdown]
# ##Acceso a datos

# %%
#Acceder a una columna por su nombre
display(apple_mobile_apps['track_name'])
# Out:
# 1                                          PAC-MAN Premium
# 2                                Evernote - stay organized
# 3          WeatherBug - Local Weather, Radar, Maps, Alerts
# 4        eBay: Best App to Buy, Sell, Save! Online Shop...
# 5                                                    Bible
#                                ...
# 11081                                                Kubik
# 11082                                    VR Roller-Coaster
# 11087                Bret Michaels Emojis + Lyric Keyboard
# 11089            VR Roller Coaster World - Virtual Reality
# 11097                         Escape the Sweet Shop Series
# Name: track_name, Length: 7197, dtype: object

# %%
#Acceder a un dato de una columna en especifica
display(apple_mobile_apps['track_name'][1])
# Out:
# 'PAC-MAN Premium'

# %% [markdown]
# ##Limpieza de datos del dataset

# %%
# Conocer cuantos elementos nulos existen por columna
print(apple_mobile_apps.isnull().sum())
#por filas
print(apple_mobile_apps.isnull().any(axis=1))
# Out:
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# dtype: int64
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 11081    False
# 11082    False
# 11087    False
# 11089    False
# 11097    False
# Length: 7197, dtype: bool

# %%
#Conocer si existen elementos duplicados en el dataset
apple_mobile_apps.duplicated()
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 11081    False
# 11082    False
# 11087    False
# 11089    False
# 11097    False
# Length: 7197, dtype: bool

# %% [markdown]
# ##Unir dos dataset

# %%
#Unir el dataset de las apps con su respectiva descripción

new_df =apple_mobile_apps.merge(apple_mobile_apps_desc,on='id',how='inner')
display(new_df.sample(10))
# Out:
#               id                      track_name_x  size_bytes_x currency  \
# 2147   690602681                         JD Sports      88594432      USD
# 1348   529652920                    Zombie Tsunami     115895296      USD
# 3350   955327604                        Jelly Jump     249597952      USD
# 830    440141669                         SHADOWGUN     517828608      USD
# 3879  1002417141  Project Color™ by The Home Depot      47817728      USD
# 4357  1039848719      Galaxy on Fire 3 - Manticore    1496265728      USD
# 2326   757228497                Skateboard Party 2    1294111744      USD
# 807    436114747                        ComicBook!      92432384      USD
# 123    309735670                 Indeed Job Search       3691520      USD
# 3506   970202342                       Solitairica     207793152      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# ...

# %% [markdown]
# ##Analisis de datos

# %%
# Análisis de correlación del dataset
apple_mobile_apps.corr()

#eliminar columnas de la correlacion
apple_mobile_apps.drop(['ipadSc_urls.num','vpp_lic'],axis=1, inplace=True)
display(apple_mobile_apps )
# Out:
#                id                                         track_name  \
# 1       281656475                                    PAC-MAN Premium
# 2       281796108                          Evernote - stay organized
# 3       281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 4       282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 5       282935706                                              Bible
# ...           ...                                                ...
# 11081  1187617475                                              Kubik
# 11082  1187682390                                  VR Roller-Coaster
# 11087  1187779532              Bret Michaels Emojis + Lyric Keyboard
# 11089  1187838770          VR Roller Coaster World - Virtual Reality
# 11097  1188375727                       Escape the Sweet Shop Series
#
#        size_bytes currency  price  rating_count_tot  rating_count_ver  \
# ...

# %%
#Obtener el juego de precio más alto
display(apple_mobile_apps.iloc[apple_mobile_apps['price'].idxmax()])
# Out:
# id                       586803362
# track_name          ウィズダム英和・和英辞典 2
# size_bytes               265569280
# currency                       USD
# price                        23.99
# rating_count_tot                 5
# rating_count_ver                 0
# user_rating                    5.0
# user_rating_ver                0.0
# ver                          2.5.1
# cont_rating                     4+
# prime_genre              Reference
# sup_devices.num                 37
# ipadSc_urls.num                  5
# lang.num                         2
# vpp_lic                          1
# Name: 1991, dtype: object

# %%
#Obtener los precios minimos, máximos y medios de las aplicaciones agrupadas por categoría
display(apple_mobile_apps.groupby('prime_genre')[['price']].aggregate(['min', np.median, max]))

display(apple_mobile_apps)
# Out:
#                   price
#                     min median     max
# prime_genre
# Book                0.0   0.00   27.99
# Business            0.0   2.99   59.99
# Catalogs            0.0   0.00    7.99
# Education           0.0   2.99  299.99
# Entertainment       0.0   0.00    9.99
# Finance             0.0   0.00    5.99
# Food & Drink        0.0   0.00   27.99
# Games               0.0   0.00   29.99
# Health & Fitness    0.0   1.99    9.99
# Lifestyle           0.0   0.00    4.99
# Medical             0.0   3.99   34.99
# Music               0.0   0.99   49.99
# Navigation          0.0   0.99   74.99
# News                0.0   0.00    3.99
# Photo & Video       0.0   0.99   22.99
# Productivity        0.0   1.99   99.99
# Reference           0.0   1.99   47.99
# Shopping            0.0   0.00    1.99
# Social Networking   0.0   0.00    9.99
# Sports              0.0   0.00   19.99
# Travel              0.0   0.00    9.99
# Utilities           0.0   0.99   24.99
# ...

# %%
#Obtener las aplicaciones por categoría de precio más alto 
apps_price_max_genre = apple_mobile_apps.groupby('prime_genre')['price'].max()

display(apps_price_max_genre)

display(new_df.groupby('prime_genre').max().reset_index())
# Out:
# prime_genre
# Book                  27.99
# Business              59.99
# Catalogs               7.99
# Education            299.99
# Entertainment          9.99
# Finance                5.99
# Food & Drink          27.99
# Games                 29.99
# Health & Fitness       9.99
# Lifestyle              4.99
# Medical               34.99
# Music                 49.99
# Navigation            74.99
# News                   3.99
# Photo & Video         22.99
# Productivity          99.99
# Reference             47.99
# Shopping               1.99
# Social Networking      9.99
# Sports                19.99
# Travel                 9.99
# Utilities             24.99
# Weather                9.99
# Name: price, dtype: float64
#           prime_genre          id                    track_name_x  \
# 0                Book  1178261698    銀魂 公式連載アプリ〜銀魂の漫画が毎週１巻読めるアプリ〜
# 1            Business  1181358720  애드픽 - 인플루언서가 되어 의미있는 수익을 올리세요!
# ...

# %%
#Obtener la cantidad de apliaciones existentes por categoría
count_apps_by_genre = apple_mobile_apps.groupby('prime_genre')['prime_genre'].count()
display(count_apps_by_genre)

print(type(count_apps_by_genre))
# Out:
# prime_genre
# Book                  112
# Business               57
# Catalogs               10
# Education             453
# Entertainment         535
# Finance               104
# Food & Drink           63
# Games                3862
# Health & Fitness      180
# Lifestyle             144
# Medical                23
# Music                 138
# Navigation             46
# News                   75
# Photo & Video         349
# Productivity          178
# Reference              64
# Shopping              122
# Social Networking     167
# Sports                114
# Travel                 81
# Utilities             248
# Weather                72
# Name: prime_genre, dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ##Gráficar datos del dataset

# %%
#Graficar la cantidad de apliaciones existentes por categoria en pastel

count_apps_by_genre.plot.pie(figsize=(70,20))

plt.show()
